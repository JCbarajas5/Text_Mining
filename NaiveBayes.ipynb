# %%
import json
import re
import nltk
import emoji
import numpy as np
import pandas as pd
from unicodedata import normalize
from wordcloud import WordCloud
from pysentimiento.preprocessing import preprocess_tweet

# %% [markdown]
# ## Dataset: SENT-COVID

# %%
with open('data/SENT-COVID.json') as file:
    data = json.load(file)
    
pd.options.mode.chained_assignment = None                                         
pd.set_option('display.max_colwidth',None)   

df = pd.DataFrame(data)
df[['Tweet','clean_tweet','Label']].head(10)
# Out:
#                                                                                                                                                                                                                       Tweet  \
# 0                                                                                                                                                  1401047081121353728-@dulcema201 @BronstonRaqsa02 Protocolo de COVID !!!!
# 1                                                                                                                                                             1258159310162595843-#COVID19 #QuedateEnCasa en Morelia Centro
# 2  1272748988626862082-México va en en aumento con el #Covid_19. Tal vez no tengamos la estabilidad de Europa o estados unidos. Para mantener 120 días en paro total. Pero podemos ser precavidos al usar la #SanaDistancia
# 3                                                                                                                                                                   1349385638722883585-@sororavirus Creo en todo y nada. 💜
# 4                                                                                                                                                                       1360615587114844161-@GobiernoMX había prometido 389
# 5                                                                                                                                                                                  1384487745033162755-Vacunación en Tonalá
# 6                                                                                                                                                                         1335343584875327494-No es cierto lo que dice @WHO
# 7                   1257755579101003776-Participa en familia con esta entretenida actividad #MejorEnCasa Manda tu vídeo a la brevedad y llevaré uno de los premios.#aquiestamos #IED #QuedateEnCasa https://t.co/BQZTpxwca2
# 8                                                                                                                                                           1317288163065401345-@lalitogonzaalez Acabar con el Coronavirus.
# 9                                                                                                                                           1255373406624776194-#InternationalDanceDay #DID #ENCASA https://t.co/crIQOdoPgG
#
#                                                                                                                                                                                    clean_tweet  \
# 0                                                                                                                                                                      Protocolo de COVID !!!!
# 1                                                                                                                                                        COVID QuedateEnCasa en Morelia Centro
# 2  México va en en aumento con el Covid. Tal vez no tengamos la estabilidad de Europa o estados unidos. Para mantener días en paro total. Pero podemos ser precavidos al usar la SanaDistancia
# 3                                                                                                                                                                       Creo en todo y nada. 💜
# 4                                                                                                                                                                             había prometido
# 5                                                                                                                                                                         Vacunación en Tonalá
# 6                                                                                                                                                                    No es cierto lo que dice
# 7                                     Participa en familia con esta entretenida actividad MejorEnCasa Manda tu vídeo a la brevedad y llevaré uno de los premios.aquiestamos IED QuedateEnCasa
# 8                                                                                                                                                                   Acabar con el Coronavirus.
# 9                                                                                                                                                            InternationalDanceDay DID ENCASA
#
#       Label
# 0    NEUTRO
# 1    NEUTRO
# 2  POSITIVO
# 3    NEUTRO
# 4  NEGATIVO
# 5  POSITIVO
# 6  NEGATIVO
# 7  POSITIVO
# 8  POSITIVO
# 9    NEUTRO

# %% [markdown]
# ## Limpieza y Normalización

# %%
def clean_text(text):
  text = re.sub(r'^RT[\s]+', '', text) # RT's
  text = re.sub(r'https?:\/\/.*[\r\n]*', '', text) # Url's
  text = re.sub(r'-', '', text) #guiones
  text = re.sub(r'_', '', text) #guiones bajos 
  text = re.sub(r'@[A-Za-z0-9_]+', '', text) #menciones
  text = re.sub(r'[~^0-9]', '', text) #numeros
  text = re.sub("\\s+", ' ', text) ##Espacios blancos dobles
  text = re.sub('\n', ' ', text) ##Saltos de linea

  pattern = r'([.])([A-Z])'
  text = re.sub(pattern, r'\1 \2', text) # Separacion de punto seguido por una mayuscula
  return text

def normalize(text):    
   text = text.lower() # Se convierte todo el texto a minúsculas
   text = re.sub(r'#', '', text) # Eliminacion de almohadillas 
   text = re.sub('http\S+', ' ', text) # Eliminación de páginas web 
   text = re.sub('emoji', '', text) # Eliminación de palabra emoji
   regex = '[\\!\\"\\#\\$\\%\\&\\\'\\(\\)\\*\\+\\,\\-\\.\\/\\:\\;\\<\\=\\>\\?\\@\\[\\\\\\]\\^_\\`\\{\\|\\}\\~]'
   text = re.sub(regex , ' ', text) # Eliminacion de signos de puntuacion
   text = re.sub("\d+", ' ', text) # Eliminación de números
   text = re.sub("\\s+", ' ', text) # Eliminación de espacios en blanco múltiples
   #text = re.sub(r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", normalize( "NFD"), 0, re.I)
   #text = normalize( 'NFC')
   return(text)

def tokenize(text):    
    text= text.split(sep = ' ')  # Tokenización por palabras individuales
    text= [token for token in text if len(token) > 1]  # Eliminación de tokens con una longitud < 2
    return(text)

def remove_punct(text):
 text = "".join(u for u in text if u not in ("?","¿", ".", ";", ":", "!","¡",'"',"%","“","”","$","&","'","\\",
                                                "*","+",",","/","<",">","=","^","•","...", "ç","π","ⓘ"))
 a,b = 'áéíóúÁÉÍÓÚ','aeiouAEIOU'
 trans = str.maketrans(a,b)     
 text = text.translate(trans) # Reemplazo de palabras acentuadas                                    
 return text

def remove_emoji(text):
  return emoji.get_emoji_regexp().sub(r'', text) # Eliminacion de emojis

def py_preprocess(text):
  return preprocess_tweet(text)  # Preprocesamiento de pysentimiento (opcional)

def split_hashtags(text):
  pat1 = r'([#])'
  text = re.sub(pat1, ' ', text) # Reemplazo de almohadillas por espacios en blanco
  pat2 = r'([a-z])([A-Z])'
  text = re.sub(pat2, r'\1 \2', text) # Separacion de minisculas seguidas por una mayuscula
  return text

# %%
df['clean_tweet'] = df['Tweet'].apply(clean_text)
df['nopunct_tweet'] = df['clean_tweet'].apply(remove_punct)
df['noemoji_tweet'] = df['nopunct_tweet'].apply(remove_emoji)
#df['pypre_tweet'] = df['noemoji_tweet'].apply(py_preprocess)
df['nohash_tweet'] = df['noemoji_tweet'].apply(split_hashtags)
df['norm_tweet'] = df['nohash_tweet'].apply(normalize)
df['tokenized_tweet'] = df['norm_tweet'].apply(tokenize)
df[['Label', 'clean_tweet', 'norm_tweet','tokenized_tweet']][150:170]
# Out:
# /var/folders/z7/lg2xbgc16657k0q2mcpjssgw0000gn/T/ipykernel_795/1100998391.py:42: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   return emoji.get_emoji_regexp().sub(r'', text) # Eliminacion de emojis
#         Label  \
# 150  POSITIVO
# 151    NEUTRO
# 152    NEUTRO
# 153  POSITIVO
# 154  POSITIVO
# 155  NEGATIVO
# 156    NEUTRO
# 157    NEUTRO
# 158  NEGATIVO
# 159  NEGATIVO
# 160  NEGATIVO
# 161    NEUTRO
# 162    NEUTRO
# 163  POSITIVO
# 164    NEUTRO
# 165    NEUTRO
# 166  NEGATIVO
# 167  POSITIVO
# 168    NEUTRO
# 169    NEUTRO
#
#                                                                                                                                                                                                                                                                              clean_tweet  \
# 150                                                                                                                                                                                                                               razón por la que quiero que me dé covid:. donar plasma
# 151                                                                                                                                                                                                                                                                      Si he leído bro
# 152  No sé si yo tomo las cosas muy directas o fue con otra intención tome un taxi el cual me hace a plática él conductor hablamos del COVID y de ahí pasamos a qué tenía piedras en el riñón ya que el bebía y que eso lo ponía muy caliente y que tenía que llegar a partir a su mujer
# 153                                                                                                                                        Los campos de golf pasarán a la historia en breve. Un uso energético sustentable y #agrovoltaico sería formidable. Fomentar economía circular
# 154                                                                                       Feliz martes!!#quedateencasa envíos a toda la República#stayhome...............#oaxaca #mexico #travel #swang #beach #lifeisgood #instapic #picoftheday #lifeisgood #love #instagood #nature…
# 155                                                                                                                                                                                         ⭕#AlertaCovid 🦠No es un juego... Tabasco acumuló nuevos casos de #COVID en las últimas horas
# 156                                                                                                                                                                                                        Para buen material sigan a mi amiga 👉🏻🍑 🔥 ¿Quieres ver un vídeo? Da click 👉🏻
# 157                                                                                                                                                                                                                                   Ustedes perdonarán lo explícito 😋pero es necesario
# 158                                                                                                                                                                           "¿Cómo puedes celebrar el #DiaInternacionalDeLaPaz? El tema está relacionado con la lucha contra la #Covid
# 159                                                                                                                                                              "Pésima política pública que generará un incremento sustancial en casos COVID en Jalisco el “🚨“. Protagonismo y drama."
# 160                                                                                 El Jefe de la Jurisdicción Sanitaria # de los dio positivo para #Covid pero huyó del Hospital del en #Oaxaca escupiendo a los pacientes y al personal médico. Todo por no recibir trato preferencial
# 161                                                                                                     que va a proceder con el aviso de en su noticiero de donde promovió a nivel Nacional que no hagan caso a las recomendaciones de para la Cuarentena el de abril ?? Urge su actuar
# 162                                                                                                                                                                                                                                                                                 🤣🤣🤣🤣
# 163                                                                                                                                                                                                                En estos tiempos nuestro mejor amigo es el cubreboca 😷 #QuédateEnCasa
# 164                                                                                                                                                                                                                                                                        Ya las llevan
# 165                                                                                                                                                                                                                            #OjosAlCielo#TimeLapse de la tarde de ayer LUNES DE MARZO
# 166                                                                                                                                                           "#CuitláhuacHundeAVeracruz En vez de preocuparse y atender la solicitud del pueblo por la amenaza de la pandemia del Covid
# 167    Tuve la oportunidad de escuchar a Don Armando Manzanero en un video por zoom reciente de la #SACM y me di cuenta el tipo de líder que era aunado a su música. Hasta nos dio un apoyo económico durante pandemia. Más personas como tú maestro 🙏🏻 tu música se queda para siempre.
# 168                                                                                                                                                                                                                                    Me vine de Colombia y ya dan clases presenciales😥
# 169                                                                                                                                                                                                           Igual deben pensar quienes piden quiten la candidatura a Salgado Macedonio
#
#                                                                                                                                                                                                                                                                               norm_tweet  \
# 150                                                                                                                                                                                                                                 razon por la que quiero que me de covid donar plasma
# 151                                                                                                                                                                                                                                                                      si he leido bro
# 152  no se si yo tomo las cosas muy directas o fue con otra intencion tome un taxi el cual me hace a platica el conductor hablamos del covid y de ahi pasamos a que tenia piedras en el riñon ya que el bebia y que eso lo ponia muy caliente y que tenia que llegar a partir a su mujer
# 153                                                                                                                                           los campos de golf pasaran a la historia en breve un uso energetico sustentable y agrovoltaico seria formidable fomentar economia circular
# 154                                                                                                                   feliz martes quedateencasa envios a toda la republica stayhome oaxaca mexico travel swang beach lifeisgood instapic picoftheday lifeisgood love instagood nature…
# 155                                                                                                                                                                                               alerta covid no es un juego tabasco acumulo nuevos casos de covid en las ultimas horas
# 156                                                                                                                                                                                                                   para buen material sigan a mi amiga quieres ver un video da click
# 157                                                                                                                                                                                                                                    ustedes perdonaran lo explicito pero es necesario
# 158                                                                                                                                                                            como puedes celebrar el dia internacional de la paz el tema esta relacionado con la lucha contra la covid
# 159                                                                                                                                                                      pesima politica publica que generara un incremento sustancial en casos covid en jalisco el protagonismo y drama
# 160                                                                                      el jefe de la jurisdiccion sanitaria de los dio positivo para covid pero huyo del hospital del en oaxaca escupiendo a los pacientes y al personal medico todo por no recibir trato preferencial
# 161                                                                                                        que va a proceder con el aviso de en su noticiero de donde promovio a nivel nacional que no hagan caso a las recomendaciones de para la cuarentena el de abril urge su actuar
# 162
# 163                                                                                                                                                                                                                 en estos tiempos nuestro mejor amigo es el cubreboca quedate en casa
# 164                                                                                                                                                                                                                                                                        ya las llevan
# 165                                                                                                                                                                                                                          ojos al cielo time lapse de la tarde de ayer lunes de marzo
# 166                                                                                                                                                           cuitlahuac hunde averacruz en vez de preocuparse y atender la solicitud del pueblo por la amenaza de la pandemia del covid
# 167           tuve la oportunidad de escuchar a don armando manzanero en un video por zoom reciente de la sacm y me di cuenta el tipo de lider que era aunado a su musica hasta nos dio un apoyo economico durante pandemia mas personas como tu maestro tu musica se queda para siempre
# 168                                                                                                                                                                                                                                     me vine de colombia y ya dan clases presenciales
# 169                                                                                                                                                                                                           igual deben pensar quienes piden quiten la candidatura a salgado macedonio
#
#                                                                                                                                                                                                                                                                                                               tokenized_tweet
# 150                                                                                                                                                                                                                                                          [razon, por, la, que, quiero, que, me, de, covid, donar, plasma]
# 151                                                                                                                                                                                                                                                                                                      [si, he, leido, bro]
# 152  [no, se, si, yo, tomo, las, cosas, muy, directas, fue, con, otra, intencion, tome, un, taxi, el, cual, me, hace, platica, el, conductor, hablamos, del, covid, de, ahi, pasamos, que, tenia, piedras, en, el, riñon, ya, que, el, bebia, que, eso, lo, ponia, muy, caliente, que, tenia, que, llegar, partir, su, mujer]
# 153                                                                                                                                                                [los, campos, de, golf, pasaran, la, historia, en, breve, un, uso, energetico, sustentable, agrovoltaico, seria, formidable, fomentar, economia, circular]
# 154                                                                                                                                      [feliz, martes, quedateencasa, envios, toda, la, republica, stayhome, oaxaca, mexico, travel, swang, beach, lifeisgood, instapic, picoftheday, lifeisgood, love, instagood, nature…]
# 155                                                                                                                                                                                                                   [alerta, covid, no, es, un, juego, tabasco, acumulo, nuevos, casos, de, covid, en, las, ultimas, horas]
# 156                                                                                                                                                                                                                                              [para, buen, material, sigan, mi, amiga, quieres, ver, un, video, da, click]
# 157                                                                                                                                                                                                                                                                 [ustedes, perdonaran, lo, explicito, pero, es, necesario]
# 158                                                                                                                                                                                             [como, puedes, celebrar, el, dia, internacional, de, la, paz, el, tema, esta, relacionado, con, la, lucha, contra, la, covid]
# 159                                                                                                                                                                                            [pesima, politica, publica, que, generara, un, incremento, sustancial, en, casos, covid, en, jalisco, el, protagonismo, drama]
# 160                                                                                               [el, jefe, de, la, jurisdiccion, sanitaria, de, los, dio, positivo, para, covid, pero, huyo, del, hospital, del, en, oaxaca, escupiendo, los, pacientes, al, personal, medico, todo, por, no, recibir, trato, preferencial]
# 161                                                                                                                   [que, va, proceder, con, el, aviso, de, en, su, noticiero, de, donde, promovio, nivel, nacional, que, no, hagan, caso, las, recomendaciones, de, para, la, cuarentena, el, de, abril, urge, su, actuar]
# 162                                                                                                                                                                                                                                                                                                                        []
# 163                                                                                                                                                                                                                                         [en, estos, tiempos, nuestro, mejor, amigo, es, el, cubreboca, quedate, en, casa]
# 164                                                                                                                                                                                                                                                                                                         [ya, las, llevan]
# 165                                                                                                                                                                                                                                                 [ojos, al, cielo, time, lapse, de, la, tarde, de, ayer, lunes, de, marzo]
# 166                                                                                                                                                                             [cuitlahuac, hunde, averacruz, en, vez, de, preocuparse, atender, la, solicitud, del, pueblo, por, la, amenaza, de, la, pandemia, del, covid]
# 167     [tuve, la, oportunidad, de, escuchar, don, armando, manzanero, en, un, video, por, zoom, reciente, de, la, sacm, me, di, cuenta, el, tipo, de, lider, que, era, aunado, su, musica, hasta, nos, dio, un, apoyo, economico, durante, pandemia, mas, personas, como, tu, maestro, tu, musica, se, queda, para, siempre]
# 168                                                                                                                                                                                                                                                                   [me, vine, de, colombia, ya, dan, clases, presenciales]
# 169                                                                                                                                                                                                                                       [igual, deben, pensar, quienes, piden, quiten, la, candidatura, salgado, macedonio]

# %% [markdown]
# ## Lemmatización

# %%
import spacy
from nltk.stem.snowball import SnowballStemmer

sp = spacy.load('es_core_news_sm')

def lemmatization(text):
    doc = sp(text)
    return ' '.join([word.lemma_ for word in doc]) 

#stemmer = SnowballStemmer('spanish')
#stemmed_spanish = [stemmer.stem(item) for item in spanish_words]

# %%
df['lem_tweet'] = df['norm_tweet'].apply(lemmatization)
df['lem_tweet'] = df['lem_tweet'].apply(remove_punct)
df['lemtokenized_tweet'] = df['lem_tweet'].apply(tokenize)
df[['Label', 'norm_tweet','lem_tweet','tokenized_tweet','lemtokenized_tweet']][200:220]
# Out:
#         Label  \
# 200  POSITIVO
# 201  POSITIVO
# 202  POSITIVO
# 203  POSITIVO
# 204    NEUTRO
# 205  NEGATIVO
# 206  POSITIVO
# 207  NEGATIVO
# 208  NEGATIVO
# 209  NEGATIVO
# 210    NEUTRO
# 211    NEUTRO
# 212  NEGATIVO
# 213  POSITIVO
# 214  POSITIVO
# 215  NEGATIVO
# 216  NEGATIVO
# 217    NEUTRO
# 218  POSITIVO
# 219  POSITIVO
#
#                                                                                                                                                                                                                                    norm_tweet  \
# 200                dos años con rumbo sntesalud y corona tips se han convertido en referente y aporte snte en la lucha ante la covid en una accion de corresponsabilidad social con el snte al uno somos todos todos somos uno ver documento
# 201                                                                                     reglasdeoro numero cuida tu salud feliz dimingo quedateen casa buen domingo sana distancia juntosporla salud xalapa devozenvozmx feliz dia del padre
# 202  en coahuila se reforzaran las medidas para que se respeten los protocolos sanitarios y prevenir un posible incremento en los contagios por covid por la temporada vacacional y ante el repunte de la pandemia que se registra en el pais
# 203                                                                    tenemos a la venta cubreboca de neopreno de primera calidad somos fabricantes pregunta por nuestros precios mayoreo y menudeo promoales cuarentena covidmx cubrebocas
# 204                                                                                                                                                                                     y apoco usted duda de todo nunca deseo el mal a nadie
# 205                                                                                                                                                                                       yo no tengo el placer de conocerla en carne y hueso
# 206                                                                                                                                                                                  la magia de la radio antes de la covid en exa queretaro
# 207                                                                                                                                                                              ellos son funcionarios publicos mas maletas que hemos tenido
# 208                                                                                                                                                                                                                     este señor es nefasto
# 209                                                                                                                                                                                                        mi tio acaba de fallecer por covid
# 210                                                                                                                                                                                                                                        ya
# 211                                                                                    ahi lo a dan buscando mi charro negro el alfa de la tribuna y futuro presidente trae mas pegue que tiene fans no solo en mexico como tambien en russia
# 212                                                                                                                                                                                         este…… cual vacunacion creo que ya se les olvido
# 213                                        copycat mas o menos año y medio de cuarentena todavia entro en mi ropa no me ha dado covid hacer pan de platano descargar tik tok comprar una freidora de aire comprar cosas por instagram vacuna
# 214                                                                                                                                                                                                                 el canto de por la mañana
# 215                                                                                                                                    mexico llega a mil muertes por covid y nuestro presidente quiere festejar el de noviembre en el zocalo
# 216                                                                                                                                                                                                                                 la covid
# 217                                                                                                                                                                                          de este si jete no hace daño y mata al covid alv
# 218                                                                                                                                                                                                    muy buenos dias llego el jueves sonrie
# 219                                       trasmision en vivo con los amigos de quedate en casa djs live sigueme en mi canal de youtube como paulk dj paulkdj live stream dj djlive djstyle quedateencasa housemusic youtube facebook mexico…
#
#                                                                                                                                                                                                                              lem_tweet  \
# 200                 dos año con rumbo sntesalud y corona tip el haber convertir en referente y aporte snte en el lucha ante el covid en uno accion de corresponsabilidad social con el snte al uno ser todo todo ser uno ver documento
# 201                                                                            reglasdeoro numero cuidar tu salud feliz dimingo quedateen casar buen domingo sano distancia juntospor el salud xalapa devozenvozmx feliz dia del padre
# 202  en coahuila el reforzar el medida para que el respetar el protocolo sanitario y prevenir uno posible incremento en el contagio por covid por el temporada vacacional y ante el repunte de el pandemia que el registrar en el pais
# 203                                                                         tener a el venta cubreboco de neopreno de primero calidad ser fabricant preguntar por nuestro precio mayoreo y menudeo promoal cuarenten covidmx cubreboca
# 204                                                                                                                                                                            y apoco usted dudar de todo nunca desear el mal a nadie
# 205                                                                                                                                                                               yo no tener el placer de conocer el en carne y hueso
# 206                                                                                                                                                                            el magia de el radio antes de el covid en exa queretaro
# 207                                                                                                                                                                              el ser funcionario publico mas maleta que haber tener
# 208                                                                                                                                                                                                             este señor ser nefasto
# 209                                                                                                                                                                                                mi tio acabar de fallecer por covid
# 210                                                                                                                                                                                                                                 ya
# 211                                                                               ahi el a dar buscar mi charro negro el alfa de el tribuna y futuro presidente traer mas pegar que tener fan no solo en mexico como tambien en russia
# 212                                                                                                                                                                                   este …… cual vacunacion creer que ya el el olvir
# 213                                 copycat mas o menos año y medio de cuarentena todavio entro en mi ropa no yo haber dar covid hacer pan de platano descargar tik tok comprar uno freidora de aire comprar cosa por instagram vacuna
# 214                                                                                                                                                                                                          el canto de por el mañana
# 215                                                                                                                             mexico llegar a mil muerte por covid y nuestro presidente querer festejar el de noviembre en el zocalo
# 216                                                                                                                                                                                                                           el covid
# 217                                                                                                                                                                                 de este si jetir no hacer daño y mata al covid alv
# 218                                                                                                                                                                                             mucho buen dias llego el jueves sonrie
# 219                                 trasmision en vivo con el amigo de quedate en casa dj live sigueme en mi canal de youtube como paulk dj paulkdj live stream dj djlivir djstyle quedateencasar housemusic youtube facebook mexico …
#
#                                                                                                                                                                                                                                                                  tokenized_tweet  \
# 200                 [dos, años, con, rumbo, sntesalud, corona, tips, se, han, convertido, en, referente, aporte, snte, en, la, lucha, ante, la, covid, en, una, accion, de, corresponsabilidad, social, con, el, snte, al, uno, somos, todos, todos, somos, uno, ver, documento]
# 201                                                                                                   [reglasdeoro, numero, cuida, tu, salud, feliz, dimingo, quedateen, casa, buen, domingo, sana, distancia, juntosporla, salud, xalapa, devozenvozmx, feliz, dia, del, padre]
# 202  [en, coahuila, se, reforzaran, las, medidas, para, que, se, respeten, los, protocolos, sanitarios, prevenir, un, posible, incremento, en, los, contagios, por, covid, por, la, temporada, vacacional, ante, el, repunte, de, la, pandemia, que, se, registra, en, el, pais]
# 203                                                                                      [tenemos, la, venta, cubreboca, de, neopreno, de, primera, calidad, somos, fabricantes, pregunta, por, nuestros, precios, mayoreo, menudeo, promoales, cuarentena, covidmx, cubrebocas]
# 204                                                                                                                                                                                                                 [apoco, usted, duda, de, todo, nunca, deseo, el, mal, nadie]
# 205                                                                                                                                                                                                                 [yo, no, tengo, el, placer, de, conocerla, en, carne, hueso]
# 206                                                                                                                                                                                                         [la, magia, de, la, radio, antes, de, la, covid, en, exa, queretaro]
# 207                                                                                                                                                                                                       [ellos, son, funcionarios, publicos, mas, maletas, que, hemos, tenido]
# 208                                                                                                                                                                                                                                                   [este, señor, es, nefasto]
# 209                                                                                                                                                                                                                                   [mi, tio, acaba, de, fallecer, por, covid]
# 210                                                                                                                                                                                                                                                                         [ya]
# 211                                                                                              [ahi, lo, dan, buscando, mi, charro, negro, el, alfa, de, la, tribuna, futuro, presidente, trae, mas, pegue, que, tiene, fans, no, solo, en, mexico, como, tambien, en, russia]
# 212                                                                                                                                                                                                                   [este……, cual, vacunacion, creo, que, ya, se, les, olvido]
# 213                                             [copycat, mas, menos, año, medio, de, cuarentena, todavia, entro, en, mi, ropa, no, me, ha, dado, covid, hacer, pan, de, platano, descargar, tik, tok, comprar, una, freidora, de, aire, comprar, cosas, por, instagram, vacuna]
# 214                                                                                                                                                                                                                                             [el, canto, de, por, la, mañana]
# 215                                                                                                                                                          [mexico, llega, mil, muertes, por, covid, nuestro, presidente, quiere, festejar, el, de, noviembre, en, el, zocalo]
# 216                                                                                                                                                                                                                                                                  [la, covid]
# 217                                                                                                                                                                                                                   [de, este, si, jete, no, hace, daño, mata, al, covid, alv]
# 218                                                                                                                                                                                                                               [muy, buenos, dias, llego, el, jueves, sonrie]
# 219                                          [trasmision, en, vivo, con, los, amigos, de, quedate, en, casa, djs, live, sigueme, en, mi, canal, de, youtube, como, paulk, dj, paulkdj, live, stream, dj, djlive, djstyle, quedateencasa, housemusic, youtube, facebook, mexico…]
#
#                                                                                                                                                                                                                                                        lemtokenized_tweet
# 200                 [dos, año, con, rumbo, sntesalud, corona, tip, el, haber, convertir, en, referente, aporte, snte, en, el, lucha, ante, el, covid, en, uno, accion, de, corresponsabilidad, social, con, el, snte, al, uno, ser, todo, todo, ser, uno, ver, documento]
# 201                                                                                        [reglasdeoro, numero, cuidar, tu, salud, feliz, dimingo, quedateen, casar, buen, domingo, sano, distancia, juntospor, el, salud, xalapa, devozenvozmx, feliz, dia, del, padre]
# 202  [en, coahuila, el, reforzar, el, medida, para, que, el, respetar, el, protocolo, sanitario, prevenir, uno, posible, incremento, en, el, contagio, por, covid, por, el, temporada, vacacional, ante, el, repunte, de, el, pandemia, que, el, registrar, en, el, pais]
# 203                                                                                          [tener, el, venta, cubreboco, de, neopreno, de, primero, calidad, ser, fabricant, preguntar, por, nuestro, precio, mayoreo, menudeo, promoal, cuarenten, covidmx, cubreboca]
# 204                                                                                                                                                                                                        [apoco, usted, dudar, de, todo, nunca, desear, el, mal, nadie]
# 205                                                                                                                                                                                                        [yo, no, tener, el, placer, de, conocer, el, en, carne, hueso]
# 206                                                                                                                                                                                                  [el, magia, de, el, radio, antes, de, el, covid, en, exa, queretaro]
# 207                                                                                                                                                                                                       [el, ser, funcionario, publico, mas, maleta, que, haber, tener]
# 208                                                                                                                                                                                                                                           [este, señor, ser, nefasto]
# 209                                                                                                                                                                                                                           [mi, tio, acabar, de, fallecer, por, covid]
# 210                                                                                                                                                                                                                                                                  [ya]
# 211                                                                                         [ahi, el, dar, buscar, mi, charro, negro, el, alfa, de, el, tribuna, futuro, presidente, traer, mas, pegar, que, tener, fan, no, solo, en, mexico, como, tambien, en, russia]
# 212                                                                                                                                                                                                           [este, ……, cual, vacunacion, creer, que, ya, el, el, olvir]
# 213                                     [copycat, mas, menos, año, medio, de, cuarentena, todavio, entro, en, mi, ropa, no, yo, haber, dar, covid, hacer, pan, de, platano, descargar, tik, tok, comprar, uno, freidora, de, aire, comprar, cosa, por, instagram, vacuna]
# 214                                                                                                                                                                                                                                      [el, canto, de, por, el, mañana]
# 215                                                                                                                                                   [mexico, llegar, mil, muerte, por, covid, nuestro, presidente, querer, festejar, el, de, noviembre, en, el, zocalo]
# 216                                                                                                                                                                                                                                                           [el, covid]
# 217                                                                                                                                                                                                          [de, este, si, jetir, no, hacer, daño, mata, al, covid, alv]
# 218                                                                                                                                                                                                                        [mucho, buen, dias, llego, el, jueves, sonrie]
# 219                                     [trasmision, en, vivo, con, el, amigo, de, quedate, en, casa, dj, live, sigueme, en, mi, canal, de, youtube, como, paulk, dj, paulkdj, live, stream, dj, djlivir, djstyle, quedateencasar, housemusic, youtube, facebook, mexico]

# %% [markdown]
# ## Nltk Stopwords

# %%
from nltk.corpus import stopwords

# Obtención de listado de stopwords del español
stop_words_esp = list(stopwords.words('spanish'))
print(stop_words_esp[:100])
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo']

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X1 = df['norm_tweet']
X2 = df['lem_tweet']
y = df['Label']

# Separamos el corupus 1) con columna 'norm_tweet' 2) con columna 'lem_tweet'
#X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.25 ,random_state=37)
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.25 ,random_state=37)

# %%
value, counts = np.unique(y_train, return_counts=True)
print(dict(zip(value, 100 * counts / sum(counts))))
value, counts = np.unique(y_test, return_counts=True)
print(dict(zip(value, 100 * counts / sum(counts))))
# Out:
# {'NEGATIVO': 33.7124526100904, 'NEUTRO': 44.911052785068534, 'POSITIVO': 21.37649460484106}
# {'NEGATIVO': 35.345581802274715, 'NEUTRO': 43.39457567804025, 'POSITIVO': 21.25984251968504}

# %% [markdown]
# ## Vectorizaciones

# %% [markdown]
# ### TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf= TfidfVectorizer(min_df= 3, ngram_range=(1,2), stop_words = stop_words_esp).fit(X_train)
                        
print('Numero de features: ' +str(len(tfidf.get_feature_names_out())))
tfidf.fit(X_train)
# Out:
# Numero de features: 2291
# TfidfVectorizer(min_df=3, ngram_range=(1, 2),
#                 stop_words=['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los',
#                             'del', 'se', 'las', 'por', 'un', 'para', 'con',
#                             'no', 'una', 'su', 'al', 'lo', 'como', 'más',
#                             'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí',
#                             'porque', ...])

# %%
# Creacion de la matriz 
X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf  = tfidf.transform(X_test)
X_train_tfidf
# Out:
# <3429x2291 sparse matrix of type '<class 'numpy.float64'>'
# 	with 23705 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

countvect = CountVectorizer(min_df=3, stop_words = stop_words_esp, ngram_range=(1,2)).fit(X_train)

print('Numero de features: ' +str(len(countvect.get_feature_names_out())))
countvect.fit(X_train)
# Out:
# Numero de features: 2291
# CountVectorizer(min_df=3, ngram_range=(1, 2),
#                 stop_words=['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los',
#                             'del', 'se', 'las', 'por', 'un', 'para', 'con',
#                             'no', 'una', 'su', 'al', 'lo', 'como', 'más',
#                             'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí',
#                             'porque', ...])

# %%
# Creacion de la matriz
X_train_cv = countvect.transform(X_train)
X_test_cv  = countvect.transform(X_test)
X_train_cv
# Out:
# <3429x2291 sparse matrix of type '<class 'numpy.int64'>'
# 	with 23705 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Vocabulario

# %%
# vocabuilario TFIDF
print(f" Número de tokens creados: {len(tfidf.get_feature_names_out())}")
tfidf.get_feature_names()

# vocabulario CountVectorizer
#print(f" Número de tokens creados: {len(countvect.get_feature_names_out())}")
#countvect.get_feature_names()
# Out:
#  Número de tokens creados: 2291
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['aaa',
#  'abierto',
#  'abrazo',
#  'abril',
#  'abrir',
#  'abuelita',
#  'abuelito',
#  'aburrido',
#  'aburrir',
#  'aca',
#  'acabar',
#  'acabar cuarentena',
#  'acabar pandemia',
#  'acapulco',
#  'acceso',
#  'accidente',
#  'accion',
#  'aceptar',
#  'acerca',
#  'aclas',
#  'acompañar',
#  'acordar',
#  'acostumbrar',
#  'actividad',
#  'activo',
#  'activo covid',
#  'actual',
#  'actualizacion',
#  'actuar',
#  'acudir',
#  'acuerdo',
#  'adecuado',
#  'adelante',
#  'adema',
#  'administracion',
#  'adomicilio',
#  'adquirir',
#  'adulto',
#  'adulto mayor',
#  'aeropuerto',
#  'afectar',
#  'agarrar',
#  'agosto',
#  'agradecer',
#  'agua',
#  'aguascalient',
#  'ah',
#  'ahh',
#  'ahi',
#  'ahora',
#  'ahora haber',
#  'ahora resultar',
#  'ahora si',
#  'ahoritir',
#  'aire',
#  'aire ılılı',
#  'aislamiento',
#  'alcoholico',
#  'alegrar',
#  'alejandro',
#  'alemania',
#  'alergia',
#  'alerta',
#  'alerta maximo',
#  'alfonso',
#  'alguien',
#  'alguien decir',
#  'alguien haber',
#  'alguien mas',
#  'alguien saber',
#  'alguien tener',
#  'algun',
#  'algun dia',
#  'alguno',
#  'allo',
#  'alrededor',
#  'alto',
#  'alto contagio',
#  'alumno',
#  'alv',
#  'alza',
#  'am',
#  'am ir',
#  'amanecer',
#  'amar',
#  'amarillo',
#  'ambiente',
#  'ambos',
#  'ambulante',
#  'amiga',
#  'amigo',
#  'amigo tener',
#  'amlo',
#  'amlo ser',
#  'amlolujo',
#  'amlolujo presidente',
#  'amor',
#  'amoren',
#  'amp',
#  'analisis',
#  'andar',
#  'andr',
#  'angel',
#  'anillo',
#  'anillo dedo',
#  'anoche',
#  'ansiedad',
#  'anterior',
#  'anti',
#  'anti covid',
#  'anticovid',
#  'anticuerpo',
#  'antivacuna',
#  'antonio',
#  'antro',
#  'anunciar',
#  'apenas',
#  'aplanar',
#  'aplicacion',
#  'aplicacion vacuna',
#  'aplicar',
#  'aplicar vacuna',
#  'aplicarar',
#  'apoco',
#  'aportar',
#  'apoyar',
#  'apoyo',
#  'app',
#  'aprovechar',
#  'aquel',
#  'aqui',
#  'ar',
#  'arder',
#  'area',
#  'area covid',
#  'argumento',
#  'arriba',
#  'arte',
#  'articulo',
#  'artista',
#  'asegurar',
#  'asesino',
#  'asi',
#  'asi ser',
#  'asistir',
#  'asqueroso',
#  'astra',
#  'astra zeneca',
#  'astrazeneca',
#  'atacar',
#  'ataque',
#  'atardecer',
#  'atencion',
#  'atender',
#  'atender paciente',
#  'atentar',
#  'atento',
#  'ato',
#  'atodo',
#  'aula',
#  'aumentar',
#  'aumento',
#  'aun',
#  'aun asi',
#  'aun haber',
#  'aun mas',
#  'aun seguir',
#  'aun tener',
#  'aunque',
#  'auto',
#  'autoridad',
#  'av',
#  'av chapultepec',
#  'avance',
#  'avanzar',
#  'avion',
#  'aviso',
#  'ay',
#  'ayer',
#  'ayuda',
#  'ayudar',
#  'ayuntamiento',
#  'año',
#  'año covid',
#  'año medio',
#  'año pasado',
#  'año poder',
#  'baja',
#  'bajar',
#  'bajar guardia',
#  'bajo',
#  'banda',
#  'base',
#  'base dato',
#  'bastante',
#  'basura',
#  'baño',
#  'beber',
#  'beisbol',
#  'bendicion',
#  'bendito',
#  'beneficio',
#  'bien',
#  'bienestar',
#  'bill',
#  'boca',
#  'boda',
#  'bola',
#  'bombero',
#  'bonito',
#  'borola',
#  'borolavirus',
#  'bot',
#  'brazo',
#  'breaking',
#  'breaking news',
#  'brigada',
#  'britanico',
#  'brote',
#  'buen',
#  'buen avance',
#  'buen desplazamiento',
#  'buen dia',
#  'buen dias',
#  'buen fin',
#  'buen lunes',
#  'buena',
#  'buena noche',
#  'buena tarde',
#  'bueno',
#  'bueno ser',
#  'buenos',
#  'buenos dias',
#  'buscar',
#  'by',
#  'cabello',
#  'cabeza',
#  'cabron',
#  'caca',
#  'cada',
#  'cada dia',
#  'caer',
#  'cafe',
#  'calderon',
#  'calidad',
#  'calle',
#  'calor',
#  'cama',
#  'cambiar',
#  'cambio',
#  'campaña',
#  'campeche',
#  'campo',
#  'canal',
#  'cancelar',
#  'cancer',
#  'cancion',
#  'cancun',
#  'cansino',
#  'cantante',
#  'cantar',
#  'cantidad',
#  'capacidad',
#  'capaz',
#  'cara',
#  'carajo',
#  'cargar',
#  'carlos',
#  'carmen',
#  'carnal',
#  'carne',
#  'caro',
#  'carrera',
#  'casa',
#  'casa buen',
#  'casa covid',
#  'casa feliz',
#  'casa junto',
#  'casa musico',
#  'casa policia',
#  'casa quedatar',
#  'casa quedatir',
#  'casa sano',
#  'casa ser',
#  'casa si',
#  'casar',
#  'casi',
#  'caso',
#  'caso activo',
#  'caso confirmado',
#  'caso covid',
#  'caso positivo',
#  'castigar',
#  'causa',
#  'causa covid',
#  'causar',
#  'cd',
#  'cdm',
#  'cdm transportar',
#  'cdmx',
#  'cel',
#  'celebrar',
#  'celular',
#  'central',
#  'centro',
#  'centro salud',
#  'centro vacunacion',
#  'cercano',
#  'cerebro',
#  'cerrado',
#  'certificado',
#  'cerveza',
#  'chairo',
#  'chamba',
#  'chapultepec',
#  'chayotero',
#  'chiapa',
#  'chica',
#  'chido',
#  'chihuahua',
#  'chimalhuacar',
#  'china',
#  'chingar',
#  'chingo',
#  'chino',
#  'chiste',
#  'chiste comediant',
#  'chiste corto',
#  'cielo',
#  'ciencia',
#  'cientifico',
#  'cierre',
#  'cierto',
#  'cifra',
#  'cinco',
#  'circular',
#  'cita',
#  'city',
#  'ciudad',
#  'ciudad mexico',
#  'ciudadania',
#  'ciudadano',
#  'ciudadano realizar',
#  'civil',
#  'claramente',
#  'claro',
#  'clase',
#  'clase linea',
#  'clase presencial',
#  'clasico',
#  'cliente',
#  'clinica',
#  'clip',
#  'clip tik',
#  'cloro',
#  'coahuila',
#  'cobertura',
#  'cobrar',
#  'cocina',
#  'cocino',
#  'colapsar',
#  'colegio',
#  'colonia',
#  'color',
#  'combate',
#  'combatir',
#  'come',
#  'comedia',
#  'comedia español',
#  'comediant',
#  'comediant comedia',
#  'comentar',
#  'comentario',
#  'comenzar',
#  'comer',
#  'comercial',
#  'comida',
#  'comodidad',
#  'compartir',
#  'compañero',
#  'completo',
#  'complicacion',
#  'compra',
#  'comprar',
#  'comprar vacuna',
#  'comun',
#  'comunicado',
#  'comunidad',
#  'comunidad escolar',
#  'conciencia',
#  'concierto',
#  'condicion',
#  'conferencia',
#  'confianza',
#  'confiar',
#  'confinamiento',
#  'confirmado',
#  'confirmar',
#  'conforme',
#  'conocer',
#  'conocimiento',
#  'consecuencia',
#  'conseguir',
#  'consejo',
#  'considerar',
#  'consulta',
#  'consumir',
#  'consumir local',
#  'contacto',
#  'contagiada',
#  'contagiado',
#  'contagiar',
#  'contagie',
#  'contagio',
#  'contagio coronavirus',
#  'contagio covid',
#  'contagio ser',
#  'contar',
#  'contener',
#  'contenido',
#  'contexto',
#  'contingencia',
#  'contingencia covid',
#  'contingencia sanitario',
#  'contingencia violencia',
#  'continuo',
#  'contrario',
#  'contratar',
#  'control',
#  'controlar',
#  'controlar pandemia',
#  'convertir',
#  'convocar',
#  'convocatoria',
#  'corazon',
#  'corona',
#  'coronaviru',
#  'coronavirus',
#  'coronavirus covid',
#  'coronavirus mx',
#  'coronavirus ser',
#  'correcto',
#  'correr',
#  'corresponder',
#  'corrupcion',
#  'corrupto',
#  'corte',
#  'corto',
#  'corto clip',
#  'cosa',
#  'cosa ser',
#  'cosa tener',
#  'costar',
#  'costo',
#  'covid',
#  'covid aun',
#  'covid coronavirus',
#  'covid covid',
#  'covid covidmx',
#  'covid estir',
#  'covid fm',
#  'covid haber',
#  'covid hacer',
#  'covid hospital',
#  'covid ir',
#  'covid junio',
#  'covid mexico',
#  'covid municipio',
#  'covid pegar',
#  'covid persona',
#  'covid poder',
#  'covid punto',
#  'covid quedar',
#  'covid quedatir',
#  'covid querer',
#  'covid ser',
#  'covid si',
#  'covid solo',
#  'covid tener',
#  'covid usar',
#  'covid vacuna',
#  'covidiota',
#  'covidmexico',
#  'covidmx',
#  'covidmx quedate',
#  'covidー',
#  'covidーmx',
#  'crear',
#  'crecimiento',
#  'creer',
#  'creer covid',
#  'creer haber',
#  'creer ser',
#  'criminal',
#  'crisis',
#  'crisis economico',
#  'crisis existencial',
#  'crisis mundial',
#  'crisis sanitario',
#  'crisis ser',
#  'critico',
#  'cronica',
#  'cruz',
#  'cualquiera',
#  'cuanta',
#  'cuanto',
#  'cuanto tiempo',
#  'cuarenten',
#  'cuarentena',
#  'cuarentena extendido',
#  'cuarentena haber',
#  'cuarentena ir',
#  'cuarentena positivo',
#  'cuarentena ser',
#  'cuarentena tener',
#  'cuarentena total',
#  'cuarentenar',
#  'cuarto',
#  'cuatro',
#  'cuauhtemoc',
#  'cubreboca',
#  'cubreboca ser',
#  'cubrir',
#  'cuello',
#  'cuenta',
#  'cuerpo',
#  'cuestion',
#  'cuidado',
#  'cuidandono',
#  'cuidar',
#  'cuidar cuidar',
#  'cuidar familia',
#  'cuidar salud',
#  'cuidarno',
#  'cuidarte',
#  'cuidate',
#  'cuidemono',
#  'cuidir',
#  'culiacar',
#  'culpa',
#  'culpa haber',
#  'culpar',
#  'cultura',
#  'cumpleaños',
#  'cumplir',
#  'cura',
#  'curar',
#  'curso',
#  'curva',
#  'cuu',
#  'dar',
#  'dar clase',
#  'dar conocer',
#  'dar covid',
#  'dar cuenta',
#  'dar dosis',
#  'dar mas',
#  'dar positivo',
#  'dato',
#  'daño',
#  'deber',
#  'deber ser',
#  'deber tener',
#  'deberiar',
#  'deberio',
#  'deberio ser',
#  'debido',
#  'deceso',
#  'deciar',
#  'decir',
#  'decir haber',
#  'decir hacer',
#  'decir ser',
#  'decir si',
#  'decision',
#  'declarar',
#  'dedo',
#  'defender',
#  'defuncion',
#  'dejar',
#  'dema',
#  'demas',
#  'demostrar',
#  'dentro',
#  'denunciar',
#  'depender',
#  'depresion',
#  'derecho',
#  'derechos',
#  'derechos humanos',
#  'desafortunadamente',
#  'desaparecer',
#  'desarrollar',
#  'desarrollo',
#  'desear',
#  'desmadre',
#  'desplazamiento',
#  'despu',
#  'despu pandemia',
#  'despu vacuna',
#  'despues',
#  'destino',
#  'desvio',
#  'deteccion',
#  'detectar',
#  'detener',
#  'dia',
#  'dia cuarentena',
#  'dia hoy',
#  'dia internacional',
#  'dia mas',
#  'dia mundial',
#  'dia noche',
#  'dia padre',
#  'diabetes',
#  'diagnostico',
#  'diar',
#  'diario',
#  'dias',
#  'dias atodo',
#  'dias cuarentena',
#  'dias haber',
#  'dicho',
#  'diciembre',
#  'diferente',
#  'dificil',
#  'dificultad',
#  'difundir',
#  'digital',
#  'diir',
#  'dinero',
#  'dio',
#  'dios',
#  'dios ser',
#  'diosito',
#  'dioxido',
#  'dioxido cloro',
#  'diputada',
#  'diputado',
#  'directo',
#  'director',
#  'disfruta',
#  'disfrutar',
#  'disminuir',
#  'disparar',
#  'disponible',
#  'disposicion',
#  'dispositivo',
#  'distancia',
#  'divertido',
#  'diz',
#  'doc',
#  'docente',
#  'doctor',
#  'doctor muerte',
#  'doctora',
#  'doler',
#  'dolor',
#  'domar',
#  'domicilio',
#  'domingo',
#  'don',
#  'donald',
#  'donald trump',
#  'donar',
#  'dormir',
#  'dos',
#  'dos año',
#  'dos semana',
#  'dos vez',
#  'dosis',
#  'dosis astra',
#  'dosis pfizer',
#  'dosis vacuna',
#  'dr',
#  'dr gatell',
#  'dr muerte',
#  'dra',
#  'duda',
#  'dueño',
#  'durango',
#  'durar',
#  'duro',
#  'echar',
#  'echar culpa',
#  'economia',
#  'economica',
#  'economico',
#  'economico salud',
#  'economio',
#  'edad',
#  'edicion',
#  'edo',
#  'edomex',
#  'edomex semaforo',
#  'educacion',
#  'educacion distancia',
#  'educativo',
#  'efectivo',
#  'efecto',
#  'efecto covid',
#  'efecto vacuna',
#  'eje',
#  'ejemplo',
#  'ejercicio',
#  'eleccion',
#  'eliminar',
#  'embarazado',
#  'emergencia',
#  'emergencia sanitario',
#  'emocion',
#  'empezar',
#  'empezo',
#  'empleado',
#  'empresa',
#  'empresario',
#  'encabezar',
#  'encasar',
#  'encerrado',
#  'encerrar',
#  'encierro',
#  'encontrar',
#  'encontre',
#  'enferma',
#  'enfermedad',
#  'enfermera',
#  'enfermero',
#  'enfermo',
#  'enfermo covid',
#  'enfrentar',
#  'enfrentar pandemia',
#  'engañar',
#  'enlace',
#  'enorme',
#  'entender',
#  'enterar',
#  'entero',
#  'entidad',
#  'entonces',
#  'entrar',
#  'entrega',
#  'entrenamiento',
#  'entrenar',
#  'entrevista',
#  'entro',
#  'enviar',
#  'envio',
#  'epidemia',
#  'epoca',
#  'equipo',
#  'equipo medico',
#  'er',
#  'escolar',
#  'escribi',
#  'escribir',
#  'escuchar',
#  'escuela',
#  'escuela publicar',
#  'esencial',
#  'esfuerzo',
#  'espacio',
#  'esparcir',
#  'españa',
#  'español',
#  'español mexico',
#  'especial',
#  'espera',
#  'esperanza',
#  'esperar',
#  'esposo',
#  'esquema',
#  'esquema vacunacion',
#  'estable',
#  'establecimiento',
#  'estadio',
#  'estario',
#  'estatal',
#  'estilo',
#  'estir',
#  'estir vacuna',
#  'estrategia',
#  'estser',
#  'estudiante',
#  'estudio',
#  'estupidez',
#  'etapa',
#  'eu',
#  'europa',
#  'evento',
#  'evitar',
#  'evitar contagio',
#  'ex',
#  'excelente',
#  'exigimo',
#  'exigir',
#  'existencial',
#  'existir',
#  'exito',
#  'experiencia',
#  'experto',
#  'explicar',
#  'exponer',
#  'extendido',
#  'extrañar',
#  'extraño',
#  'facebook',
#  'facil',
#  'fallecer',
#  'fallecido',
#  'fallecimiento',
#  'fallecio',
#  'falso',
#  'falta',
#  'faltar',
#  'familia',
#  'familiar',
#  'fan',
#  'far',
#  'farmaceutica',
#  'fase',
#  'fauci',
#  'favor',
#  'favor quedate',
#  'favorito',
#  'fe',
#  'febrero',
#  'fecha',
#  'federal',
#  'felicidad',
#  'felipe',
#  'feliz',
#  'feliz dia',
#  'feliz jueves',
#  'feliz lunes',
#  'feliz martes',
#  'feliz miercol',
#  'feliz sabado',
#  'feliz viernes',
#  'fenomeno',
#  'feo',
#  'fernando',
#  'festejar',
#  'fiesta',
#  'fila',
#  'fin',
#  'fin semana',
#  'final',
#  'financiero',
#  'finanza',
#  'fit',
#  'fm',
#  'food',
#  'forma',
#  'formar',
#  'foto',
#  'fracaso',
#  'francia',
#  'francisco',
#  'frase',
#  'frenar',
#  'frente',
#  'frontera',
#  'ft',
#  'fuente',
#  'fuerte',
#  'fuerza',
#  'fumador',
#  'funcionar',
#  'funcionario',
#  'futuro',
#  'gabinete',
#  'gana',
#  'ganar',
#  'ganar seguidor',
#  'gasto',
#  'gatell',
#  'gato',
#  'generacion',
#  'general',
#  'generar',
#  'genero',
#  'gente',
#  'gente ir',
#  'gente ser',
#  'go',
#  'gobernador',
#  'gobernar',
#  'gobierno',
#  'gobierno federal',
#  'gobierno haber',
#  'google',
#  'gracia',
#  'gracias',
#  'gracias pandemia',
#  'gradual',
#  'gran',
#  'grande',
#  'gratis',
#  'gratuito',
#  'grave',
#  'grave ser',
#  'gripa',
#  'gritar',
#  'grupo',
#  'gto',
#  'guadalajara',
#  'guadalupe',
#  'guanajuato',
#  'guardar',
#  'guardia',
#  'gubernamental',
#  'guerra',
#  'guerrero',
#  'gustar',
#  'gustariar',
#  'gusto',
#  'haber',
#  'haber caso',
#  'haber contagiar',
#  'haber covid',
#  'haber dar',
#  'haber evitar',
#  'haber forma',
#  'haber gente',
#  'haber haber',
#  'haber hacer',
#  'haber ir',
#  'haber leer',
#  'haber llegar',
#  'haber mas',
#  'haber millon',
#  'haber pasar',
#  'haber poner',
#  'haber prueba',
#  'haber ser',
#  'haber tener',
#  'haber traer',
#  'haber vacuna',
#  'haber ver',
#  'haber vivir',
#  'habia',
#  'habiar',
#  'habito',
#  'hablar',
#  'habra',
#  'habrar',
#  'habriar',
#  'hacer',
#  'hacer año',
#  'hacer caso',
#  'hacer cuarentena',
#  'hacer dias',
#  'hacer ejercicio',
#  'hacer falta',
#  'hacer mes',
#  'hacer prueba',
#  'hacer semana',
#  'hacer ser',
#  'hacer tiempo',
#  'hacia',
#  'hambre',
#  'hanna',
#  'happy',
#  'har',
#  'hariar',
#  'harto',
#  'hecho',
#  'hermano',
#  'hermosillo',
#  'hermoso',
#  'hero',
#  'heroes',
#  'herramienta',
#  'hidalgo',
#  'hija',
#  'hijo',
#  'hilo',
#  'historia',
#  'historico',
#  'hogar',
#  'hola',
#  'holar',
#  'hombre',
#  'home',
#  'homeoffice',
#  'homir',
#  'honor',
#  'hora',
#  'horario',
#  'horrible',
#  'hospital',
#  'hospital general',
#  'hospital privado',
#  'hospitalario',
#  'hospitalizacion',
#  'hospitalizado',
#  'hoy',
#  'hoy ser',
#  'hoy si',
#  'hoy tener',
#  ...]

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn import naive_bayes
from sklearn import metrics

nb = naive_bayes.MultinomialNB()
nb.fit(X_train_cv, y_train)

predictions_nb = nb.predict(X_test_cv)
metrics.f1_score(y_test, predictions_nb, average='micro')
# Out:
# 0.5818022747156606

# %%
print(nb.score(X_train_cv,y_train))
print(nb.score(X_test_cv,y_test))
print(nb.classes_)
predictions_nb
# Out:
# 0.7471566054243219
# 0.5818022747156606
# ['NEGATIVO' 'NEUTRO' 'POSITIVO']
# array(['POSITIVO', 'NEUTRO', 'NEGATIVO', ..., 'NEGATIVO', 'NEUTRO',
#        'NEGATIVO'], dtype='<U8')

# %%
from sklearn.metrics import confusion_matrix,classification_report

new = np.asarray(y_test)
confusion_matrix(predictions_nb,y_test)
print(classification_report(predictions_nb, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVO       0.68      0.58      0.63       472
#       NEUTRO       0.59      0.60      0.60       488
#     POSITIVO       0.40      0.53      0.46       183
#
#     accuracy                           0.58      1143
#    macro avg       0.56      0.57      0.56      1143
# weighted avg       0.60      0.58      0.59      1143
